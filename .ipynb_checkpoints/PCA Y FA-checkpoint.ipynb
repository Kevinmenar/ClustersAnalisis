# %%
import pandas as pd
import numpy as np
import sklearn.datasets
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from factor_analyzer import FactorAnalyzer
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import TruncatedSVD

df = pd.read_csv("OutTest.csv")
columns_counts = len(df.columns)
print(df.head())
scaler = MinMaxScaler()
scaler.fit(df)
X = scaler.transform(df)

for i in range(columns_counts):
    fa = FactorAnalyzer(rotation=None, n_factors=i+1)
    fa.fit(X)
    print("Componentes de PCA")
    print(i)
    print(fa.loadings_)
    
for i in range(columns_counts):
    svd = TruncatedSVD(n_components=i, algorithm='randomized', random_state=0)
    X_svd = svd.fit_transform(X)
    print("Componentes de PCA")
    print(i)
    print(X_svd)

for i in range(columns_counts):
    pca = PCA(n_components=i, 
               copy=True, 
               whiten=False, 
               svd_solver='auto', 
               tol=0.0, 
               iterated_power='auto', 
               random_state=None)
    pca.fit(X)
    print("Componentes de PCA")
    print(i)
    print(pca.explained_variance_ratio_)
    #print(pca.singular_values_)
    print(pca.components_)
# Out:
#    DN_HistogramMode_5  DN_HistogramMode_10  CO_f1ecac  CO_FirstMin_ac  \
# 0           -0.210122            -0.511695       27.0             4.0
# 1           -0.605269            -0.855454       18.0             4.0
# 2           -1.060000            -0.880000       99.0           311.0
# 3            0.294597             0.504122       11.0            19.0
# 4            0.568828            -0.092716        6.0            11.0
#
#    CO_HistogramAMI_even_2_5  CO_trev_1_num  MD_hrv_classic_pnn40  \
# 0                  0.325476       0.067122              0.910256
# 1                  0.245421       0.030455              0.967949
# 2                  1.410000       0.000099              0.286000
# 3                  0.533078      -0.028764              0.925926
# 4                  0.282813       0.047331              0.963964
#
#    SB_BinaryStats_mean_longstretch1  SB_TransitionMatrix_3ac_sumdiagcov  \
# 0                              56.0                            0.023333
# ...
